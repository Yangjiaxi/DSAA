# %%
import numpy as np

# %%
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sb.set()
plt.rcParams['figure.figsize'] = [4, 4]
plt.rcParams['figure.dpi'] = 144
plt.rcParams['axes.unicode_minus'] = False
sb.set_style("darkgrid")

# %%
data_1 = [[10, 9],
       [100, 341],
       [200, 2914],
       [300, 8708],
       [400, 20958],
       [500, 40458],
       [600, 75067],
       [700, 112113],
       [800, 165617],
       [900, 233748],
       [1000, 321565]]

data_2 = [[10, 3],
         [50, 6],
         [100, 10],
         [200, 17],
         [300, 26],
         [400, 31],
         [500, 40],
         [600, 48],
         [700, 52],
         [800, 67]]
_data = np.array(data_2)

# %%
plt.plot(_data[:, 0], _data[:, 1])

# %%
# plt.plot(_data[:, 0], _data[:, 1] ** (1/3))
